# %% [markdown]
# # Assignment 3 - Group 4 (Diego, Katty, Ronald, Claudia)

# %% [markdown]
# 1. Inspect this dataset `./_data/bogota_firms.xlsx` and show some descriptive statistics of it.

# %% [markdown]
# First we need to import our panda library

# %%
import pandas as pd

# %% [markdown]
# Then we assign file path

# %%
db_path= r"C:\Users\HP\Documents\GitHub\QLAB_Summer_Python\MediaLab_Summer_Python\_data\bogota_firms.xlsx"

# %%
database_bogota = r"C:\Users\HP\Documents\GitHub\QLAB_Summer_Python\MediaLab_Summer_Python\_data\bogota_firms.xlsx"

# %% [markdown]
# If we want to read the file and crate a dataframe with pandas, we should use the function 'read_excel' adding the database_bogota variable

# %%
data_frame = pd.read_excel(database_bogota, sheet_name='Results')

# %% [markdown]
# We'd like to show a random sample of 5 rows from the dataset, here it is:

# %%
data_frame.sample(5)
# Out:
#       Unnamed: 0          Company name Latin alphabet Country ISO code  \
# 7922      7923.0           RUEDA SERRANO PAOLA ANDREA               CO
# 7220      7221.0                       OTUNAGRO S A S               CO
# 617        618.0  SERVICIOS HOTELEROS DE BOLIVAR LTDA               CO
# 854        855.0               ESSENTIAL COLOMBIA SAS               CO
# 729        730.0              LABORATORIOS THANI LTDA               CO
#
#      City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 7922                GIRON                             4621.0
# 7220              PEREIRA                             4621.0
# 617             CARTAGENA                             5510.0
# 854           BUCARAMANGA                             4675.0
# 729                BOGOTA                             2110.0
#
#      Consolidation code  Last avail. year  \
# 7922                 U1              2017
# 7220                 U1              2022
# 617                  U1              2020
# 854                  U1              2022
# 729                  U1              2011
#
#      Operating revenue (Turnover)\nth LCU 2023  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                       n.a.
# 854                                       n.a.
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth USD 2023  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                       n.a.
# 854                                       n.a.
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth LCU 2022  ...  \
# 7922                                      n.a.  ...
# 7220                               3973903.024  ...
# 617                                       n.a.  ...
# 854                                4657751.878  ...
# 729                                       n.a.  ...
#
#      Operating revenue (Turnover)\nth LCU 2015  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                       n.a.
# 854                                1655021.058
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth USD 2015  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                       n.a.
# 854                                 525.491924
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth LCU 2014  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                    2435542
# 854                                       n.a.
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth USD 2014  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                1018.007388
# 854                                       n.a.
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth LCU 2013  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                    2635542
# 854                                     727472
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth USD 2013  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                1370.850332
# 854                                 378.387152
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth LCU 2012  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                    2866377
# 854                                       n.a.
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth USD 2012  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                1618.014231
# 854                                       n.a.
# 729                                       n.a.
#
#      Operating revenue (Turnover)\nth LCU 2011  \
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                    3386347
# 854                                       n.a.
# 729                                    1887000
#
#      Operating revenue (Turnover)\nth USD 2011
# 7922                                      n.a.
# 7220                                      n.a.
# 617                                1743.113709
# 854                                       n.a.
# 729                                 971.328564
#
# [5 rows x 33 columns]

# %% [markdown]
# 2. Reshape the dataset from wide to long at year level. Drop columns if they are in Dollars. Keep columns from Operating revenue (Turnover) th LCU 2023 to the end, and the name of the firm.

# %% [markdown]
# 3. Rename the columns and use short names for each column. This new name should be shorter than 20 characters.

# %% [markdown]
# First we need to define a dictionary with the new column names:

# %%
new_columns = {
    "Company name Latin alphabet": "Co. Nm Ltin Alpha",
    "Country ISO code": "Cntry ISO cd",
    "City Latin Alphabet": "City L Alpha", "Consolidation code": "Conso code", "Last avail. year": "LAY", "Operating revenue (Turnover)": "Rev LCU", }

# %% [markdown]
# Then we have to use a function to rename the columns, here it is:

# %%
data_frame.rename(columns=new_columns, inplace=True)

# %% [markdown]
# To show how we rename the columns we take 5 random columns to see the results:

# %%
data_frame.sample(5)
# Out:
#       Unnamed: 0                                Co. Nm Ltin Alpha  \
# 1301      1302.0  EMPRESA DE PLANES Y SERVICIOS DE COLOMBIA S A S
# 6802      6803.0       EMPRESA DE DESECHOS ESPECIALES S A S E S P
# 9195      9196.0        ASOCIACION COLOMBIANA DE MEDICINA INTERNA
# 6959      6960.0            UNION INTERNACIONAL DE NEGOCIOS S A S
# 9105      9106.0      COOPERATIVA DE TRABAJO ASOCIADO JIREH SALUD
#
#      Cntry ISO cd City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 1301           CO               CUCUTA                             4299.0
# 6802           CO              PEREIRA                             3812.0
# 9195           CO               BOGOTA                             9499.0
# 6959           CO             MEDELLIN                             4690.0
# 9105           CO                 CALI                             8690.0
#
#      Conso code   LAY Operating revenue (Turnover)\nth LCU 2023  \
# 1301         U1  2022                                      n.a.
# 6802         U1  2022                                      n.a.
# 9195         U1  2018                                      n.a.
# 6959         U1  2022                                      n.a.
# 9105         U1  2009                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2023  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                      n.a.
# 6959                                      n.a.
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2022  ...  \
# 1301                               4601853.198  ...
# 6802                                   4010798  ...
# 9195                                      n.a.  ...
# 6959                               3998082.563  ...
# 9105                                      n.a.  ...
#
#      Operating revenue (Turnover)\nth LCU 2015  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                               1516165.935
# 6959                                      n.a.
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2015  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                481.403515
# 6959                                      n.a.
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2014  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                 726914.48
# 6959                                 74922.036
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2014  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                303.835578
# 6959                                 31.315899
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2013  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                               1273837.728
# 6959                                      n.a.
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2013  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                662.573722
# 6959                                      n.a.
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2012  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                      n.a.
# 6959                                      n.a.
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2012  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                      n.a.
# 6959                                      n.a.
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2011  \
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                      n.a.
# 6959                                      n.a.
# 9105                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2011
# 1301                                      n.a.
# 6802                                      n.a.
# 9195                                      n.a.
# 6959                                      n.a.
# 9105                                      n.a.
#
# [5 rows x 33 columns]

# %% [markdown]
# 4. Generate a dictionary with the definition of all the columns in your dataset.

# %% [markdown]
# 5. After reshaping the data, you should replicate the long data, but instead of using methods of pandas, you have to use for loop.b

# %%
# New Data with Loop

for key, value in name_dictionary.items() :
    print[key]
    print[value]

# %% [markdown]
# 6. After reshaping the data, you should replicate the long data, but instead of using methods of pandas, you have to use while loop.
