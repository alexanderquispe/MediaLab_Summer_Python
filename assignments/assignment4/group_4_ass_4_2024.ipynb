# %% [markdown]
# # Assignment 4

# %% [markdown]
# 1. Inspect this dataset `./_data/bogota_firms.xlsx` and show some descriptive statistics of it.
# 2. Reshape the dataset from wide to long at year level. Drop columns if they are in Dollars. Keep columns from Operating revenue (Turnover) th LCU 2023 to the end, and the name of the firm.
# 3. Rename the columns and use short names for each column. This new name should be shorter than 20 characters.
# 4. Generate a dictionary with the definition of all the columns in your dataset.
# 5. Generate a function named as calling_data that take as input the `name of the firm  or list of names (firm_name)` and `(start_year, end_year)`. The function should return a tuple with a dataframe with the same format as the one resulting from task 1-4, and your dictionary of columns. The function should work without `end_year`. It means it only takes `start_year`.

# %%
1.

# %%
#First we need to import our panda library

import pandas as pd

# %%
#Then we assign file path

db_path= r"C:\Users\Claudia\Documents\GitHub\MediaLab_Summer_Python\_data\bogota_firms.xlsx"

# %%
db_bogota = r"C:\Users\Claudia\Documents\GitHub\MediaLab_Summer_Python\_data\bogota_firms.xlsx"

# %%
#We want to read the file so we need to create a dataframe with pandas, we should use the function 'read_excel' adding the database_bogota variable
data_frame = pd.read_excel(db_bogota, sheet_name='Results')

# %%
#We'd like to show a random sample of 8 rows from the dataset, here it is:
data_frame.sample(8)
# Out:
#       Unnamed: 0                        Company name Latin alphabet  \
# 441        442.0                               CORTES ORTIZ ALFREDO
# 9413      9414.0                 B R G SOCIEDAD DE INVERSIONES LTDA
# 2140      2141.0                                      ARMIGON S A S
# 5835      5836.0                           METRO BIKES BOGOTA S A S
# 4325      4326.0                                       ACABAL S A S
# 5032      5033.0        AGRICOLA LA CASCADA CORREA Y COMPANIA S C A
# 7888      7889.0  EMPRESA DE SERVICIOS PUBLICOS DE RESTREPO AGUA...
# 3501      3502.0                                  TMCONSULTING LTDA
#
#      Country ISO code City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 441                CO               BOGOTA                             2219.0
# 9413               CO                 CHIA                             4110.0
# 2140               CO             MEDELLIN                             4299.0
# ...

# %% [markdown]
# 2. Reshape the dataset from wide to long at year level. Drop columns if they are in Dollars. Keep columns from Operating revenue (Turnover) th LCU 2023 to the end, and the name of the firm.

# %%
#Firstly, to do the new dataset, we need to drop the columns with dolars data through a loop and drop function

delete_usd=[column for column in data_frame.columns if 'USD' in column]  
delete_usd = data_frame.drop(columns=delete_usd)

# %%
#Then we create a new loop for maintain the column of operating revenue
maintain_data=[column for column in delete_usd.columns if column == 'Operating revenue (Turnover)\nth LCU 2023' or column == 'Company name Latin alphabet']
maintain_data = delete_usd[maintain_data]

# %%
#Now we create a new loop for reshape the dataset with the years and using the melt function
reshaped_table = maintain_data.melt(id_vars=['Company name Latin alphabet'], var_name='Year', value_name='LCU')
reshaped_table['Year'] = reshaped_table['Year'].str.extract('(\d{4})')

# %%
#Finally we resolve

reshaped_table
# Out:
#                             Company name Latin alphabet  Year   LCU
# 0     CONSORCIO CONTINENTAL PARA EL DESARROLLO SOSTE...  2023  n.a.
# 1                 AGRET CARGA NACIONAL Y ESPECIAL S A S  2023  n.a.
# 2                              DINASTIA INVERSIONES S A  2023  n.a.
# 3                          BACKBONE COMUNICACIONES LTDA  2023  n.a.
# 4                                   MACAOL ESPINOSA SAS  2023  n.a.
# ...                                                 ...   ...   ...
# 9995                                     GRADISPAN LTDA  2023  n.a.
# 9996    CONTACTO ESTRATEGICO OUTSOURCING CONTABLE S A S  2023  n.a.
# 9997                         JOSHUA CAFE IRLANDES S A S  2023  n.a.
# 9998                    PROYECTO AGUAS DEL BOSQUE S A S  2023  n.a.
# 9999                      GRUPO INVERSIONES SYNERGY SAS  2023  n.a.
#
# [10000 rows x 3 columns]

# %% [markdown]
# 3. Rename the columns and use short names for each column. This new name should be shorter than 20 characters.

# %%
#First we need to define a dictionary with the new column names:
new_columns = {"Company name Latin alphabet": "data1",
    "Country ISO code": "data2",
    "City\nLatin Alphabet": "data3", "NACE Rev. 2, core code (4 digits)": "data4", "Last avail. year": "data5", "Operating revenue (Turnover)\nth LCU 2023": "data6", "Operating revenue (Turnover)\nth USD 2023": "data 7"}

# %%
#Then we have to use a function to rename the columns, here it is:

data_frame.rename(columns=new_columns, inplace=True)

# %%
#Finally we resolved:

data_frame.sample(7)
# Out:
#       Unnamed: 0                                              data1 data2  \
# 8761      8762.0                            FUNDACION CON LUZ VERDE    CO
# 1371      1372.0             SONAR EVENTOS & PRODUCCIONES S A S BIC    CO
# 2036      2037.0  COOPERATIVA MULTIACTIVA DE HOGARES COMUNITARIO...    CO
# 3823      3824.0                            TEJIDOS PLASTICOS S A S    CO
# 4812      4813.0                       URIBE GARCIA Y COMPANIA LTDA    CO
# 9837      9838.0   CENTRO DE ESPECIALIDADES MEDICO QUIRURGICAS LTDA    CO
# 319        320.0            RESTREPO ROJAS PINEDA ARQUITECTOS S A S    CO
#
#             data3   data8 data4  data5 data6 data 7  \
# 8761      COROZAL  9499.0    U1   2022  n.a.   n.a.
# 1371  BUCARAMANGA  9004.0    U1   2022  n.a.   n.a.
# 2036    MANIZALES     NaN    U1   2010  n.a.   n.a.
# 3823       BOGOTA  1392.0    U1   2022  n.a.   n.a.
# 4812       BOGOTA  1410.0    U1   2008  n.a.   n.a.
# 9837       BOGOTA  8621.0    U1   2021  n.a.   n.a.
# ...

# %% [markdown]
# 4. Generate a dictionary with the definition of all the columns in your dataset.

# %%
column_definitions = {
    'data1': 'Name of the company',
    'data2': 'Code',
    'data3': 'City', 'data4': 'core code', 'data5': 'year'}

# Print the dictionary
for column , definition in column_definitions.items():
    print(f"{column}: {definition}")
# Out:
# data1: Name of the company
# data2: Code
# data3: City
# data4: core code
# data5: year

# %% [markdown]
# 5. Generate a function named as calling_data that take as input the name of the firm or list of names (firm_name) and (start_year, end_year). The function should return a tuple with a dataframe with the same format as the one resulting from task 1-4, and your dictionary of columns. The function should work without end_year. It means it only takes start_year.

# %%
data_frame = pd.read_excel(db_bogota, sheet_name='Results')

# %%
#We have to know the types of our columns
data_frame.dtypes
# Out:
# Unnamed: 0                                   float64
# Company name Latin alphabet                   object
# Country ISO code                              object
# City\nLatin Alphabet                          object
# NACE Rev. 2, core code (4 digits)            float64
# Consolidation code                            object
# Last avail. year                               int64
# Operating revenue (Turnover)\nth LCU 2023     object
# Operating revenue (Turnover)\nth USD 2023     object
# Operating revenue (Turnover)\nth LCU 2022     object
# Operating revenue (Turnover)\nth USD 2022     object
# Operating revenue (Turnover)\nth LCU 2021     object
# Operating revenue (Turnover)\nth USD 2021     object
# Operating revenue (Turnover)\nth LCU 2020     object
# Operating revenue (Turnover)\nth USD 2020     object
# Operating revenue (Turnover)\nth LCU 2019     object
# Operating revenue (Turnover)\nth USD 2019     object
# Operating revenue (Turnover)\nth LCU 2018     object
# ...

# %%
firm_name = data_frame['Company name Latin alphabet']
start_year = 2010
end_year = 2023

# %%
def calling_data(firm_name, start_year, end_year=None):
    # Filtering data based on firm_name and start_year
    filtered_data = data_frame[(data_frame['Company name Latin alphabet'].isin(firm_name)) & (data_frame['Last avail. year'])]

    # If end_year is provided, filter data for the specified range
    if end_year:
        filtered_data = filtered_data[(filtered_data['Last avail. year'] >= start_year) & (filtered_data['Last avail. year'] <= end_year)]
    
    else :
        filtered_data = data_frame[(data_frame['Company name Latin alphabet'].isin(firm_name)) & (data_frame['Last avail. year'] == start_year)]

    # Return a tuple
    return filtered_data

# %%
calling_data(firm_name, start_year, end_year)
# Out:
#       Unnamed: 0           Company name Latin alphabet Country ISO code  \
# 9           10.0                   CREAMODA TEXTIL S A               CO
# 32          33.0        ALZATE CASTANO FAIBEL DE JESUS               CO
# 35          36.0       UNO EQUIPOS Y SUMINISTROS S A S               CO
# 50          51.0              MONSALVO CONTRERAS ELIAS               CO
# 55          56.0                     NAHER TRADING S A               CO
# ...          ...                                   ...              ...
# 9978      9979.0                BARON ALFONSO GERONIMO               CO
# 9989      9990.0      CONSTRUCTORA DICOMAQ S A S ZOMAC               CO
# 9991      9992.0                    AE TRANSPORTES SAS               CO
# 9993      9994.0  FONDO DE EMPLEADOS DE COMCEL EL CUAL               CO
# 9998      9999.0       PROYECTO AGUAS DEL BOSQUE S A S               CO
#
#      City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# ...
