# %%
#Assignment 4


##1. Inspect this dataset ./_data/bogota_firms.xlsx and show some descriptive statistics of it.
##2.Reshape the dataset from wide to long at year level. Drop columns if they are in Dollars. Keep columns from Operating revenue (Turnover) th LCU 2023 to the end, and the name of the firm.
##3.Rename the columns and use short names for each column. This new name should be shorter than 20 characters.
##4.Generate a dictionary with the definition of all the columns in your dataset.
##5.Generate a function named as calling_data that take as input the name of the firm or list of names (firm_name) and (start_year, end_year). The function should return a tuple with a dataframe with the same format as the one resulting from task 1-4, and your dictionary of columns. The function should work without end_year. It means it only takes start_year.

# %%
##1. Exercise 1

# We import pandas library and load the data set
import pandas as pd
data = pd.read_excel('../../_data/bogota_firms.xlsx', sheet_name='Results')
data.head()
# Out:
#    Unnamed: 0                        Company name Latin alphabet  \
# 0         1.0  CONSORCIO CONTINENTAL PARA EL DESARROLLO SOSTE...
# 1         2.0              AGRET CARGA NACIONAL Y ESPECIAL S A S
# 2         3.0                           DINASTIA INVERSIONES S A
# 3         4.0                       BACKBONE COMUNICACIONES LTDA
# 4         5.0                                MACAOL ESPINOSA SAS
#
#   Country ISO code City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 0               CO                 CALI                             4299.0
# 1               CO               BOGOTA                             4941.0
# 2               CO         BARRANQUILLA                             4771.0
# 3               CO               BOGOTA                             6190.0
# 4               CO               BOGOTA                             6820.0
#
#   Consolidation code  Last avail. year  \
# 0                 U1              2022
# 1                 U1              2022
# ...

# %%
# With data shape, we obtain the number of rows and columns
fil_col_ = data.shape

# With data shape, we obtain the number of total elements
elementos =data.size

print (fil_col_, elementos)
# Out:
# (10000, 33) 330000

# %%
################################################################   EXERCISE 2    #####################

########### PARTE1

# Specific characters to look for
specific_chars = 'USD'

# Identify columns that contain the specific characters
columns_to_drop = [column for column in data.columns if specific_chars in column]

# Drop these columns
data.drop(columns =columns_to_drop, inplace=True)

# The modified DataFrame
data.head()
# Out:
#    Unnamed: 0                        Company name Latin alphabet  \
# 0         1.0  CONSORCIO CONTINENTAL PARA EL DESARROLLO SOSTE...
# 1         2.0              AGRET CARGA NACIONAL Y ESPECIAL S A S
# 2         3.0                           DINASTIA INVERSIONES S A
# 3         4.0                       BACKBONE COMUNICACIONES LTDA
# 4         5.0                                MACAOL ESPINOSA SAS
#
#   Country ISO code City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 0               CO                 CALI                             4299.0
# 1               CO               BOGOTA                             4941.0
# 2               CO         BARRANQUILLA                             4771.0
# 3               CO               BOGOTA                             6190.0
# 4               CO               BOGOTA                             6820.0
#
#   Consolidation code  Last avail. year  \
# 0                 U1              2022
# 1                 U1              2022
# ...

# %%
########### PART 2 (PART 2 OF EXCERCISE 2) ############

# Specific characters to look for
specific_chars = 'Company '
specific_chars_2 ='Operating revenue'

# Identify columns that contain the specific characters
columns_to_keep_1 = [column for column in data.columns if specific_chars  in column]
columns_to_keep_2 = [column for column in data.columns if specific_chars_2 in column]


# Drop these columns
columns_to_keep_3 = columns_to_keep_1 +  columns_to_keep_2

# Select only the columns to keep
data = data[columns_to_keep_3]
# The modified DataFrame
data.head()
# Out:
#                          Company name Latin alphabet  \
# 0  CONSORCIO CONTINENTAL PARA EL DESARROLLO SOSTE...
# 1              AGRET CARGA NACIONAL Y ESPECIAL S A S
# 2                           DINASTIA INVERSIONES S A
# 3                       BACKBONE COMUNICACIONES LTDA
# 4                                MACAOL ESPINOSA SAS
#
#   Operating revenue (Turnover)\nth LCU 2023  \
# 0                                      n.a.
# 1                                      n.a.
# 2                                      n.a.
# 3                                      n.a.
# 4                                      n.a.
#
#   Operating revenue (Turnover)\nth LCU 2022  \
# 0                                   4769810
# 1                               4769796.503
# 2                                      n.a.
# 3                               4769348.616
# 4                                   4769148
#
#   Operating revenue (Turnover)\nth LCU 2021  \
# 0                                  11542995
# ...

# %%
########################################## Reshaping  ##########################################


# Reshaping the dataset from wide to long format at the year level
# 'id_vars' is used to keep the 'Company name Latin alphabet' column as is
# 'var_name' names the new column that will contain the years
# 'value_name' names the new column that will contain the operating revenues
reshaped_df = data.melt(id_vars=["Company name Latin alphabet"], var_name="Year", value_name="Operating Revenue LCU")

# Extracting the year from the 'Year' column
# The lambda function takes each entry in 'Year', splits it by spaces, and takes the last part (which is the year)
reshaped_df['Year'] = reshaped_df['Year'].apply(lambda x: x.split()[-1])

reshaped_df.head()  # Displaying the first 5 rows of the reshaped dataframe
# Out:
#                          Company name Latin alphabet  Year  \
# 0  CONSORCIO CONTINENTAL PARA EL DESARROLLO SOSTE...  2023
# 1              AGRET CARGA NACIONAL Y ESPECIAL S A S  2023
# 2                           DINASTIA INVERSIONES S A  2023
# 3                       BACKBONE COMUNICACIONES LTDA  2023
# 4                                MACAOL ESPINOSA SAS  2023
#
#   Operating Revenue LCU
# 0                  n.a.
# 1                  n.a.
# 2                  n.a.
# 3                  n.a.
# 4                  n.a.

# %%
########################################## EXCERCISE 3 ##########################################
# Renaming the first column to 'Company name'
data.rename(columns={data.columns[0]: 'Company name'}, inplace=True)

# Renaming the other columns to only the last 8 characters
data.columns = [col if i == 0 else col[-8:] for i, col in enumerate(data.columns)]

data.head()
# Out:
#                                         Company name LCU 2023     LCU 2022  \
# 0  CONSORCIO CONTINENTAL PARA EL DESARROLLO SOSTE...     n.a.      4769810
# 1              AGRET CARGA NACIONAL Y ESPECIAL S A S     n.a.  4769796.503
# 2                           DINASTIA INVERSIONES S A     n.a.         n.a.
# 3                       BACKBONE COMUNICACIONES LTDA     n.a.  4769348.616
# 4                                MACAOL ESPINOSA SAS     n.a.      4769148
#
#       LCU 2021    LCU 2020    LCU 2019    LCU 2018     LCU 2017    LCU 2016  \
# 0     11542995     1595190     1830135     1781000      1445138    41586490
# 1  5259328.067        n.a.  612146.462  139395.337         n.a.        n.a.
# 2         n.a.        n.a.        n.a.        n.a.         n.a.        n.a.
# 3  1701322.858  879949.217  653859.797  735620.995  1516456.869  1304091.03
# 4      3624485      715275      743340     9490473       673342     1449218
#
#    LCU 2015    LCU 2014  LCU 2013 LCU 2012 LCU 2011
# ...

# %%
########################################## EXCERCISE 4 ##########################################



# Generating a dictionary with the definition of all the columns in the filtered_df dataset

column_definitions = {
    "Company name Latin alphabet": "Name of the company in Latin alphabet",
}

# Looping through the remaining columns, which represent years
for col in data.columns[1:]:
    year = col.split()[-1]
    column_definitions[col] = f"Operating revenue in local currency unit (LCU) for the year {year}"

column_definitions
# Out:
# {'Company name Latin alphabet': 'Name of the company in Latin alphabet',
#  'alphabet': 'Operating revenue in local currency unit (LCU) for the year alphabet',
#  'ISO code': 'Operating revenue in local currency unit (LCU) for the year code',
#  'Alphabet': 'Operating revenue in local currency unit (LCU) for the year Alphabet',
#  ' digits)': 'Operating revenue in local currency unit (LCU) for the year digits)',
#  'ion code': 'Operating revenue in local currency unit (LCU) for the year code',
#  'il. year': 'Operating revenue in local currency unit (LCU) for the year year',
#  'LCU 2023': 'Operating revenue in local currency unit (LCU) for the year 2023',
#  'LCU 2022': 'Operating revenue in local currency unit (LCU) for the year 2022',
#  'LCU 2021': 'Operating revenue in local currency unit (LCU) for the year 2021',
#  'LCU 2020': 'Operating revenue in local currency unit (LCU) for the year 2020',
#  'LCU 2019': 'Operating revenue in local currency unit (LCU) for the year 2019',
# ...
