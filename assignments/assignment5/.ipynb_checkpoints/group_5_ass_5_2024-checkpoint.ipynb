# %% [markdown]
# # Assignment 5
#
# In this assignment, your task is to scrape data from the given [link](https://resultadoshistorico.onpe.gob.pe/EG2021/). You'll need to extract all votes for departments, provinces, and districts. Follow these steps:
#
# 1. Click on 'Resumen General'.
# 2. Select 'Presidencial', and then choose 'Peru'.
# 3. Scrape the data and generate a final table with the following columns: department, province, district, political_organization, total_votes.
#
# Your code must execute successfully; any errors will result in a zero grade. Ensure you test your code thoroughly.

# %% [markdown]
# ## Exercise 1

# %%
## First, install the libraries
# !pip install selenium
# !pip install webdriver-manager
# !pip install lxml
# !pip install lxmunidecodel
# Out:
# Collecting selenium
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/dc/72/96b5afa16908f9abc7c24b70adfd3a46c9740eb728ddfeab28379e38eaf9/selenium-4.16.0-py3-none-any.whl.metadata
#   Downloading selenium-4.16.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\anaconda\lib\site-packages (from selenium) (1.26.16)
# Collecting trio~=0.17 (from selenium)
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/14/fb/9299cf74953f473a15accfdbe2c15218e766bae8c796f2567c83bae03e98/trio-0.24.0-py3-none-any.whl.metadata
#   Downloading trio-0.24.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\anaconda\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\anaconda\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\anaconda\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\anaconda\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Obtaining dependency information for outcome from https://files.pythonhosted.org/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl.metadata
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: cffi>=1.14 in c:\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\anaconda\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\anaconda\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# Downloading selenium-4.16.0-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 10.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.1/10.0 MB 11.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.6/10.0 MB 11.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/10.0 MB 11.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.5/10.0 MB 11.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.9/10.0 MB 10.2 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/10.0 MB 10.4 MB/s eta 0:00:01
#    --------------- ------------------------ 4.0/10.0 MB 11.0 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/10.0 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.8/10.0 MB 10.5 MB/s eta 0:00:01
#    --------------------- ------------------ 5.3/10.0 MB 10.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/10.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------- -------------- 6.4/10.0 MB 10.7 MB/s eta 0:00:01
#    --------------------------- ------------ 6.9/10.0 MB 10.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.5/10.0 MB 10.8 MB/s eta 0:00:01
#    -------------------------------- ------- 8.0/10.0 MB 10.9 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.0 MB 10.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.1/10.0 MB 11.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  9.9/10.0 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 10.3 MB/s eta 0:00:00
# Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#    ---------------------------------------- 0.0/460.2 kB ? eta -:--:--
#    -------------------------------- ------ 389.1/460.2 kB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 460.2/460.2 kB 9.6 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: sniffio, outcome, h11, wsproto, trio, trio-websocket, selenium
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.16.0 sniffio-1.3.0 trio-0.24.0 trio-websocket-0.11.1 wsproto-1.2.0
# Collecting webdriver-manager
#   Obtaining dependency information for webdriver-manager from https://files.pythonhosted.org/packages/b1/51/b5c11cf739ac4eecde611794a0ec9df420d0239d51e73bc19eb44f02b48b/webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata
#   Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\anaconda\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\anaconda\lib\site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->webdriver-manager) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->webdriver-manager) (2023.7.22)
# Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.1
# Requirement already satisfied: lxml in c:\anaconda\lib\site-packages (4.9.3)
# ERROR: Could not find a version that satisfies the requirement lxmunidecodel (from versions: none)
# ERROR: No matching distribution found for lxmunidecodel

# %%
# Library to manipulate browser
from selenium import webdriver

# Then, we call ChromeDriver
from webdriver_manager.chrome import ChromeDriverManager
import re
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import pandas as pd

# And import select class
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import unidecode
from selenium.webdriver.support.ui import Select

# %%
pwd
# Out:
# 'C:\\Users\\pamea\\OneDrive\\Documentos\\Github\\MediaLab_Summer_Python\\assignments\\assignment5'

# %%
## Here, we download the driver using ChromeDriverManager by the path
service = Service(executable_path="C:/Users/pamea/OneDrive/Documentos/Github/MediaLab_Summer_Python/Lecture_7/chromedriver-win64/chromedriver.exe")

driver = webdriver.Chrome(service = service)

## Paste the url
url = 'https://resultadoshistorico.onpe.gob.pe/EG2021/'
driver.get(url)

## We put this to maximize the window
driver.maximize_window()

## We put this to click on 'Resumen General'
driver.find_element(By.XPATH, '/html/body/onpe-root/onpe-home-onpe/div[1]/div/div/div/div[2]/div[1]/div/div/a/div[2]/div').click()
time.sleep(2)

## EXERCISE 2 

## We put this to click on 'Presidencial'
driver.find_element(By.XPATH, '/html/body/onpe-root/onpe-layout-container/onpe-menu/div/nav/div/div/div[2]/div/div[2]/a').click()
time.sleep(2)

# Then, we put this to click on 'Perú'
driver.find_element(By.XPATH, '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[1]/select/option[2]').click()
time.sleep(2)

## Ejercicio 3 

# Tabla Votos
table_path = driver.find_element(By.XPATH, '/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[4]')

table_html = table_path.get_attribute( 'innerHTML' )

table = pd.read_html( table_html )
table[0]
# Out:
#     TOTAL DE VOTOS  TOTAL DE VOTOS.1  \
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
# 5              NaN               NaN
# 6              NaN               NaN
# 7              NaN               NaN
# 8              NaN               NaN
# 9              NaN               NaN
# 10             NaN               NaN
# 11             NaN               NaN
# 12             NaN               NaN
# 13             NaN               NaN
# 14             NaN               NaN
# 15             NaN               NaN
# 16             NaN               NaN
# 17             NaN               NaN
# 18             NaN               NaN
# 19             NaN               NaN
# 20             NaN               NaN
# 21             NaN               NaN
# 22             NaN               NaN
#
#                                   TOTAL DE VOTOS.2 TOTAL DE VOTOS.3  \
# 0                                              NaN            TOTAL
# 1                     PARTIDO NACIONALISTA PERUANO           228955
# 2   EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD            64217
# 3                                   PARTIDO MORADO           319176
# 4                               PERU PATRIA SEGURA            54341
# 5                                VICTORIA NACIONAL           802957
# 6                                   ACCION POPULAR          1294681
# 7      AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL          1652682
# 8                                     PODEMOS PERU           808559
# 9                               JUNTOS POR EL PERU          1111407
# 10                 PARTIDO POPULAR CRISTIANO - PPC           282007
# 11                                  FUERZA POPULAR          1907896
# 12                               UNION POR EL PERU           100312
# 13                              RENOVACION POPULAR          1657575
# 14                     RENACIMIENTO UNIDO NACIONAL            88634
# 15                  PARTIDO DEMOCRATICO SOMOS PERU           237367
# 16            PARTIDO POLITICO NACIONAL PERU LIBRE          2714152
# 17                              DEMOCRACIA DIRECTA            50184
# 18                        ALIANZA PARA EL PROGRESO           863955
# 19                          TOTAL DE VOTOS VÁLIDOS         14239057
# 20                                 VOTOS EN BLANCO          2159535
# 21                                     VOTOS NULOS          1087222
# 22                         TOTAL DE VOTOS EMITIDOS         17485814
#
#    TOTAL DE VOTOS.4 TOTAL DE VOTOS.5
# 0          %VÁLIDOS        %EMITIDOS
# 1            1.608%           1.309%
# 2            0.451%           0.367%
# 3            2.242%           1.825%
# 4            0.382%           0.311%
# 5            5.639%           4.592%
# 6            9.092%           7.404%
# 7           11.607%           9.452%
# 8            5.678%           4.624%
# 9            7.805%           6.356%
# 10           1.981%           1.613%
# 11          13.399%          10.911%
# 12           0.704%           0.574%
# 13          11.641%           9.480%
# 14           0.622%           0.507%
# 15           1.667%           1.357%
# 16          19.061%          15.522%
# 17           0.352%           0.287%
# 18           6.068%           4.941%
# 19         100.000%          81.432%
# 20              NaN          12.350%
# 21              NaN           6.218%
# 22              NaN         100.000%

# %%
# Clean Table
import unidecode
import pandas as pd

# Assuming table is a DataFrame
# Clean Table
row_new_columns = table[0].iloc[0, 2:]
clean_columns = row_new_columns \
    .str.replace(" ", "_") \
    .str.lower().str.replace("%", "share_") \
    .apply(lambda x: unidecode.unidecode(x) if isinstance(x, str) else x) \
    .tolist()

# Selecting specific columns
table_clean = table[0].iloc[1:, 2:].copy()
table_clean
# Out:
#                                   TOTAL DE VOTOS.2 TOTAL DE VOTOS.3  \
# 1                     PARTIDO NACIONALISTA PERUANO           228955
# 2   EL FRENTE AMPLIO POR JUSTICIA, VIDA Y LIBERTAD            64217
# 3                                   PARTIDO MORADO           319176
# 4                               PERU PATRIA SEGURA            54341
# 5                                VICTORIA NACIONAL           802957
# 6                                   ACCION POPULAR          1294681
# 7      AVANZA PAIS - PARTIDO DE INTEGRACION SOCIAL          1652682
# 8                                     PODEMOS PERU           808559
# 9                               JUNTOS POR EL PERU          1111407
# 10                 PARTIDO POPULAR CRISTIANO - PPC           282007
# 11                                  FUERZA POPULAR          1907896
# 12                               UNION POR EL PERU           100312
# 13                              RENOVACION POPULAR          1657575
# 14                     RENACIMIENTO UNIDO NACIONAL            88634
# 15                  PARTIDO DEMOCRATICO SOMOS PERU           237367
# 16            PARTIDO POLITICO NACIONAL PERU LIBRE          2714152
# 17                              DEMOCRACIA DIRECTA            50184
# 18                        ALIANZA PARA EL PROGRESO           863955
# 19                          TOTAL DE VOTOS VÁLIDOS         14239057
# 20                                 VOTOS EN BLANCO          2159535
# 21                                     VOTOS NULOS          1087222
# 22                         TOTAL DE VOTOS EMITIDOS         17485814
#
#    TOTAL DE VOTOS.4 TOTAL DE VOTOS.5
# 1            1.608%           1.309%
# 2            0.451%           0.367%
# 3            2.242%           1.825%
# 4            0.382%           0.311%
# 5            5.639%           4.592%
# 6            9.092%           7.404%
# 7           11.607%           9.452%
# 8            5.678%           4.624%
# 9            7.805%           6.356%
# 10           1.981%           1.613%
# 11          13.399%          10.911%
# 12           0.704%           0.574%
# 13          11.641%           9.480%
# 14           0.622%           0.507%
# 15           1.667%           1.357%
# 16          19.061%          15.522%
# 17           0.352%           0.287%
# 18           6.068%           4.941%
# 19         100.000%          81.432%
# 20              NaN          12.350%
# 21              NaN           6.218%
# 22              NaN         100.000%

# %%
all_tables = {}


for dpt_idx in range(26):
    try:
        
        
        dpt = Select(driver.find_element(By.XPATH, "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[2]/select"))
        
        
        department = dpt.options[dpt_idx]

        
        dpt_name = department.text

        
        if dpt_name != "--TODOS--":
            
            
            department.click()

            
            prov = Select(driver.find_element(By.XPATH, "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select"))
            
            
            num_prov_options = len(prov.options)

            
            for prov_idx in range(num_prov_options):
                try:
                    
                    
                    prov = Select(driver.find_element(By.XPATH, "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[3]/select"))
                    
                    
                    province = prov.options[prov_idx]

                    
                    prov_name = province.text
                    
                    
                    if prov_name != "--TODOS--":
                        
                        
                        province.click()

                        
                        dist = Select(driver.find_element(By.XPATH, "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select"))
                        
                        
                        num_dist_options = len(dist.options)

                        
                        for dist_idx in range(num_dist_options):
                            
                            try:
                                
                                
                                dist = Select(driver.find_element(By.XPATH, "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[3]/div[1]/div[1]/div/div/div[4]/select"))
                                
                                
                                district = dist.options[dist_idx]

                                
                                dist_name = district.text

                                
                                if dist_name != "-- SELECCIONE --":
                                    
                                    district.click()

                                    
                                    ubigeo = driver.current_url.split("/")[ -1 ]

                                   
                                    table_path = driver.find_element(By.XPATH, "/html/body/onpe-root/onpe-layout-container/onpe-onpe-epres-re/div[1]/div[4]/div[1]/div[3]/div" )
                                    table_html = table_path.get_attribute( 'innerHTML' )
                                    
                                    
                                    table = pd.read_html( table_html )

                                   
                                    row_new_columns = table[ 0 ].iloc[ 0 , 2: ]
                                    clean_columns = row_new_columns \
                                                          .str.replace(" ","_") \
                                                          .str.lower().str.replace( "%", "share_") \
                                                          .apply( lambda x : unidecode.unidecode( x ) ) \
                                                          .tolist()

                                    
                                    table_clean = table[0].iloc[ 1:, 2: ].copy()

                                   
                                    table_clean.columns = clean_columns

                                    
                                    table_clean[ 'department' ] = dpt_name
                                    table_clean[ 'province' ]   = prov_name
                                    table_clean[ 'district' ]   = dist_name


                                   
                                    all_tables[ ubigeo ] = table_clean

                            except Exception as dist_error:
                                print(f"Error in district loop: {dist_error}")
                                

                except Exception as prov_error:
                    print(f"Error in province loop: {prov_error}")
    

    except Exception as dpt_error:
        print(f"Error in department loop: {dpt_error}")
# Out:
# Error in district loop: Message: unknown error: unhandled inspector error: {"code":-32000,"message":"Promise was collected"}
#   (Session info: chrome=120.0.6099.218)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6CB712142+3514994]
# 	(No symbol) [0x00007FF6CB330CE2]
# 	(No symbol) [0x00007FF6CB1D76AA]
# 	(No symbol) [0x00007FF6CB1C112C]
# 	(No symbol) [0x00007FF6CB1BEE85]
# 	(No symbol) [0x00007FF6CB1BF7CE]
# 	(No symbol) [0x00007FF6CB1DCA9B]
# 	(No symbol) [0x00007FF6CB1DF6F7]
# 	(No symbol) [0x00007FF6CB26316B]
# 	(No symbol) [0x00007FF6CB245FEA]
# 	(No symbol) [0x00007FF6CB2628F6]
# 	(No symbol) [0x00007FF6CB245D93]
# 	(No symbol) [0x00007FF6CB214BDC]
# 	(No symbol) [0x00007FF6CB215C64]
# 	GetHandleVerifier [0x00007FF6CB73E16B+3695259]
# 	GetHandleVerifier [0x00007FF6CB796737+4057191]
# 	GetHandleVerifier [0x00007FF6CB78E4E3+4023827]
# 	GetHandleVerifier [0x00007FF6CB4604F9+689705]
# 	(No symbol) [0x00007FF6CB33C048]
# 	(No symbol) [0x00007FF6CB338044]
# 	(No symbol) [0x00007FF6CB3381C9]
# 	(No symbol) [0x00007FF6CB3288C4]
# 	BaseThreadInitThunk [0x00007FF90E1B257D+29]
# 	RtlUserThreadStart [0x00007FF90F4EAA58+40]
