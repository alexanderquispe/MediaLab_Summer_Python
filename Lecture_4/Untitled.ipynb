# %%
import pandas as pd

extraction_fish = pd.read_csv( r"..\_data\production_fish.csv" )

# %%
extraction_fish
# Out:
#     year  Consumo Industrial - Anchoveta  \
# 0   2005                     8628.396000
# 1   2006                     5891.838000
# 2   2007                     6084.713000
# 3   2008                     6159.387000
# 4   2009                     5828.636000
# 5   2010                     3330.413040
# 6   2011                     7000.092781
# 7   2012                     3693.871080
# 8   2013                     4754.118210
# 9   2014                     2255.453460
# 10  2015                     3616.481500
# 11  2016                     2732.733740
# 12  2017                     3165.490240
# 13  2018                     6072.887839
# 14  2019                     3381.437222
# 15  2020                     4314.558220
#
#     Consumo Humano - Congelado - Concha de abanico  \
# 0                                        13.537000
# 1                                        14.714000
# 2                                        19.937000
# ...

# %%
### Stadisticts values of extraction_fish

extraction_fish.head()
# Out:
#    year  Consumo Industrial - Anchoveta  \
# 0  2005                        8628.396
# 1  2006                        5891.838
# 2  2007                        6084.713
# 3  2008                        6159.387
# 4  2009                        5828.636
#
#    Consumo Humano - Congelado - Concha de abanico  \
# 0                                       13.537000
# 1                                       14.714000
# 2                                       19.937000
# 3                                       18.790000
# 4                                       24.634372
#
#    Consumo Humano - Congelado - Langostino  \
# 0                                 9.021000
# 1                                11.295000
# 2                                13.548000
# 3                                12.817000
# 4                                11.877399
#
#    Consumo Humano - Congelado - Merluza  \
# 0                             23.279000
# 1                             25.189000
# ...

# %%
extraction_fish.head(3)

col_names = extraction_fish.columns.to_list()[ 1:-1 ]

for col in col_names:
    extraction_fish[ f'%_{col}' ]  = extraction_fish[ f'{col}' ] * 100 / extraction_fish[ 'total_production' ]

extraction_fish.head()
# Out:
#    year  Consumo Industrial - Anchoveta  \
# 0  2005                        8628.396
# 1  2006                        5891.838
# 2  2007                        6084.713
# 3  2008                        6159.387
# 4  2009                        5828.636
#
#    Consumo Humano - Congelado - Concha de abanico  \
# 0                                       13.537000
# 1                                       14.714000
# 2                                       19.937000
# 3                                       18.790000
# 4                                       24.634372
#
#    Consumo Humano - Congelado - Langostino  \
# 0                                 9.021000
# 1                                11.295000
# 2                                13.548000
# 3                                12.817000
# 4                                11.877399
#
#    Consumo Humano - Congelado - Merluza  \
# 0                             23.279000
# 1                             25.189000
# ...

# %%
col_names = extraction_fish.columns.to_list()[ 2:6 ]

col_names.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 3
#       1 col_names = extraction_fish.columns.to_list()[ 2:6 ]
# ----> 3 col_names.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
# Displaying the original DataFrame
print("Original DataFrame:")
print(col_names)

# Mapping of old column names to new short names
column_mapping = {'Consumo Humano - Congelado - Concha de abanico': 'CAbanico',
                  'Consumo Humano - Congelado - Langostino': 'Langostino',
                  'Consumo Humano - Congelado - Merluza': 'Merluza',
                  'Consumo Humano - Congelado - Calamar gigante': 'CGigante',
                 }

print(column_mapping)
# Out:
# Original DataFrame:
# ['Consumo Humano - Congelado - Concha de abanico', 'Consumo Humano - Congelado - Langostino', 'Consumo Humano - Congelado - Merluza', 'Consumo Humano - Congelado - Calamar gigante']
# {'Consumo Humano - Congelado - Concha de abanico': 'CAbanico', 'Consumo Humano - Congelado - Langostino': 'Langostino', 'Consumo Humano - Congelado - Merluza': 'Merluza', 'Consumo Humano - Congelado - Calamar gigante': 'CGigante'}

# %%
# Loop to rename columns
for old_name, new_name in column_mapping.items():
    col_names.rename = col_names(columns={old_name: new_name})
    
col_names_rename.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 # Loop to rename columns
#       2 for old_name, new_name in column_mapping.items():
# ----> 3     col_names.rename = col_names(columns={old_name: new_name})
#       5 col_names_rename.head()
#
# TypeError: 'list' object is not callable
